# %%
#import the required libraries
import string
import re
from numpy import array, argmax, random, take
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, RepeatVector
from keras.preprocessing.text import Tokenizer
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras import optimizers
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_colwidth', 200)
from sklearn.model_selection import train_test_split

# %%
#filename = this will be the pathway for the swahili and hindi datasets.
#This function is basically for taking in the contents of the dataset.
def read_text(filename):
        # open the file
        file = open(filename, mode='rt', encoding='utf-8')
        
        # read all text
        text = file.read()
        file.close()
        return text

# %%
#This function is to split the text into swahili-english pairs and hindi-english pairs. This will help in translating English sentences(input) to Swahili/Hindi (output)
def to_lines(text):
      sents = text.strip().split('\n')
      sents = [i.split('\t') for i in sents]
      return sents

# %%
#So now, we are taking in a filename which will basically be the hindi or swahili dataset and we are splitting them as mentioned above.
data = read_text("swahili.txt")
lang_eng = to_lines(data)
lang_eng
# Out:
# [['Any recent chills, night sweats or fever?',
#   'Kuumwa , kutokwa majasho usiku au joto lolote hivi majuzi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#  ['Have you gained or lost weight without trying?',
#   'Je, umeongeza au kupunguza uzani bila kukusudia?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#  ['Have you been tired?',
#   'Je, umewahi kuchoka?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)'],
#  ['Any dry or itchy areas?',
#   'Maeneo yoyote yaliyokauka au yanayowasha?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)'],
#  ['Any rashes, bumps, or sores anywhere?',
#   'Vipele, majipu au vidonda popote?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)'],
#  ['Do you bruise easily?',
#   'Je, wewe huchibuka kwa urahisi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)'],
#  ['Have any of your moles changed in color, shape or size?Any changes in hair or nails?',
#   'Je, magamba yako yamegeuka rangi, umbo au ukubwa? Je pamekuwa na mabadiliko katika nyweleau kucha zako?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)'],
#  ['Have you had any dizziness (room spinning) or light-headedness?',
#   'Umewahi kuwa na kisuunzi (kizunguzungu) au kichwa kuwa kizito?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)'],
#  ['Have you fainted or passed out?',
#   'Umewahi kuzirai?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)'],
#  ['Do you have headaches? ',
#   'Waumwa na kichwa? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #2122375 (Pfirsichbaeumchen)'],
#  ['Have you ever had any head trauma?',
#   'Umewahi kupata mshtuko kichwani?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #626467 (jakov)'],
#  ['Any problems with your eyes, e.g., itching, burning, watering, discharge, redness, pain?',
#   'Matatizo yoyote kwenye macho yako kama vile kuwashwa, kuungua, kutoa machozi, kutoa matongo, kuwa mekundu au kuwa na maumivu?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #2122378 (Pfirsichbaeumchen)'],
#  ['Any problems with your vision, e.g., double vision, blurred vision?',
#   'Shida katika kuona mfano: kuona vitu viwili viwili, kutokuona vyema?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #8597806 (Roujin)'],
#  ['Do you wear glasses or contacts?',
#   ' Je, wewe huvaa miwani au lensi ziwekwazo machoni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #6102432 (mailohilohi) & #4942826 (Hans_Adler)'],
#  ['Any problems with your ears, e.g., ringing, pain, discharge, hearing problems?',
#   'Matatizo yoyote kwenye masikio yako kama vile kusikia sauti sikioni, maumivu masikioni, kutoa usaha, matatizo ya kusikia?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #6625701 (Felixjp)'],
#  ['Any history of frequent ear infections?',
#   'Matatizo ya awali ya maambukizo ya masikio? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #380701 (cburgmer)'],
#  ['Have you ever had tubes in your ears?',
#   'Umewahi kuwekewa mipira kwenye masikio yako?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#  ['Do you wear a hearing aid?',
#   'Je wewe hutumia kifaa cha kukusaidia kusikia vizuri?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #131 (MUIRIEL)'],
#  ['Any problems with your nose, eg, bloody nose, runny nose, congestion, sneezing, change in mucus?',
#   'Matatizo yoyote kwenye pua yako? Kama vile mnoga - kutokwa damu puani, makamasi yanayotoka na kutiririka kila wakati, kuzibika kwa pua, kupiga chafya, mabadiliko kwenye makamasi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #1169837 (Haehnchenpaella)'],
#  ['Any recent sore throat or sores in your mouth?',
#   'Vidonda kooni au vidonda mdomoni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #5828607 (CK) & #6643977 (Felixjp)'],
#  ['Any problem with your teeth or gums, e.g., pain, bleeding or loose teeth?',
#   'Matatizo ya meno au ufizi kama vile kuuma, kutoka damu au meno kung’oka?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #547386 (Espi)'],
#  ['Any hoarseness?',
#   'Kuwasha kwa koo?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #5677459 (eric2)'],
#  ['Any lumps or bumps in your neck?',
#   'Vimbe au kufura shingoni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #4944510 (Hans_Adler)'],
#  ['Any soreness, pain or stiffness?',
#   'Vidonda, uchungu au kukwama shingoni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941621 (Hans_Adler)'],
#  ['Any pain with movement?',
#   'Je, una matatizo yoyote kugeuka kwa shingo?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941622 (Hans_Adler)'],
#  ['Relax.',
#   'Entspann dich.',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #3172031 (dinkel_girl)'],
#  ['Any trouble with breathing or shortness of breath?',
#   'Je, una shida yoyote ya kupumua?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #1958697 (Tamy)'],
#  ['Any shortness of breath with exercise or movement or How far can you walk without having to stop?',
#   'Je, una matatizo yoyote kupumua unapofanya mazoezi au unapotembea? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #8597807 (Roujin)'],
#  ['Any pain when you take a deep breath?',
#   'Unatembea umbali gani bila ya kupumzika?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#  ['Any cough or phlegm production?',
#   'Kukohoa kwokote au kuwa na makamasi puani au kooni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #4659632 (AC)'],
#  ['Have you ever had tuberculosis?',
#   'Umewahi kuugua ugonjwa wa kifua kikuu?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5227364 (jaz1313)'],
#  ['Have you been exposed to anyone with tuberculosis?',
#   'Umewahi kutangamana na yeyote anayeugua ugonjwa wa kifua kikuu?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5946689 (list)'],
#  ['Do you have any chest pains?',
#   'Je,una maumivu yoyote kifuani?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #957535 (Sudajaengi)'],
#  ['Do you feel like your heart races or skips beats?',
#   'Je, wahisi kuwa moyo wako una mapigo ya kasi au hata kukosa mapigo?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #4768107 (garborg) & #8597873 (Roujin)'],
#  ['Do you have shortness of breath at rest or with small amounts of exertion?',
#   'Je, una upungufu fulani unapopumua?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #4769344 (garborg) & #8227448 (MisterTrouser)'],
#  ['Can you lie flat in bed without shortness of breath?',
#   'Je, waweza kujilaza twaa kitandani bila ya kuwa na matatizo ya kupumua?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155388 (Pfirsichbaeumchen)'],
#  ['Do you ever awake at night short of breath?',
#   'Je, wewe huzinduka usingizini usiku kwa sababu ya tatizo la kupumua?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155390 (Pfirsichbaeumchen)'],
#  ['Have you ever been told you have a heart murmur?',
#   'Je, umewahi kuambiwa una shida ya moyo? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5253180 (christian42)'],
#  ['Have you ever had rheumatic fever?',
#   'Je, umewahi kuwa na maumivu ya viungo na kufura / kuvimba viungoni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#  ['Any pains in your legs or buttocks when you walk? ',
#   'Maumivu yoyote miguuni au makalioni / matakoni unapotembea? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5622431 (list)'],
#  ['Does it get better when you stop?',
#   'Inakua bora unaposimama?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin) '],
#  ['Any loss of hair from your legs or sores that don’t heal?',
#   'Kutoweka kwa malaika miguuni au vidonda visivyopona?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #8597813 (Roujin)'],
#  ['Any problems with leg swelling or varicose veins?',
#   'Je, miguu yako inafura au mshipa mikubwa kujitokeza miguuni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #455377 (MUIRIEL)'],
#  ['Any breast lumps, pain or soreness?',
#   'Je, una vimbe matitini, uchungu wowote au vidonda vyovyote?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #455452 (Zaghawa)'],
#  ['Any nipple discharge?',
#   'Je, unatoa usaha wowote kwenye chuchu?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #1808892 (Tamy)'],
#  ['Any rashes, color changes or skin changes?',
#   'Je, una vipele, kubadilika kwa rangi matitini au ngozi kubadilika?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401396 (Esperantostern)'],
#  ['When was your last mammogram?',
#   'Ni lini mara ya mwisho kufanyiwa uchunguzi wa matiti yako kubaini iwapo una saratani ya matiti?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401397 (Esperantostern)'],
#  ['Any belly ache/abdominal pain?',
#   'Kuumwa kwa tumbo kwa aina yoyote?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #4659678 (AC)'],
#  ['Any nausea, vomiting, cramping, diarrhea?',
#   'Kichefuchefu chochote, kutapika, tumbo kusokota, kuhara / kuendesha?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846595 (Pfirsichbaeumchen)'],
#  ['Any heartburn?',
#   'Kiungulia chochote?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846597 (Pfirsichbaeumchen)'],
#  ['Any constipation?',
#   'Haja ngumu yoyote?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1854006 (Pfirsichbaeumchen)'],
#  ['Any blood in the stool or black tarry stool? Any food intolerance?',
#   'Damu yoyote kwenye haja kubwa / kinyesi? Kutokubalika kwa chakula tumboni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942958 (Hans_Adler)'],
#  ['Any problems with gallstones? ',
#   'Damu yoyote kwenye haja kubwa / kinyesi? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942959 (Hans_Adler)'],
#  ['Hepatitis?',
#   'Kutokubalika kwa chakula tumboni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#  ['Any increase in frequency of urination?',
#   'Kuongezeka kwa mara / idadi ya nyakati wa kukojoa?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942960 (Hans_Adler)'],
#  ['Do you have to get up at night to urinate? ',
#   'Je, wewe huamka na kukojoa usiku? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942961 (Hans_Adler)'],
#  ['How many times?',
#   ' Mara ngapi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#  ['Do you feel like you need to urinate, then cannot?',
#   'Je, wahisi kutaka kukojoa kisha unashindwa kukojoa?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942963 (Hans_Adler)'],
#  ['Any pain with urination?',
#   'Je, una uchungu wowote unapokojoa?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #358382 (MUIRIEL)'],
#  ['Any blood in your urine?',
#   'Je, una damu kwenye mkojo wako?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #3935374 (gianich73) & #3235040 (Manfredo)'],
#  ['Any pain in your back or flanks?',
#   'Una maumivu mgongoni au kiunoni?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #1755073 (Eldad) & #4659717 (AC)'],
#  ['Any weakness?',
#   'Una upungufu au udhaifu wowote misulini?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7141489 (Luiaard)'],
#  ['Any joint pain, redness, swelling, heat?',
#   'Je, kuvimba au joto misulini?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7141490 (Luiaard)'],
#  ['Any morning stiffness?',
#   'Je, misuli yako hukauka na kuwa migumu wakati wa asubuhi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #7290637 (shekitten) & #4781463 (Tamy)'],
#  ['Any limited movement?',
#   'Je, unapungukiwa ukitembea?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #5828611 (CK) & #7091837 (Luiaard)'],
#  ['Any muscle cramping or pain?',
#   'Je, misuli yako hujisokota na kuwa na uchungu mkali?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #341452 (MUIRIEL)'],
#  ['Any numbness or tingling in fingers, toes, arms or legs?',
#   'Je, vidole vya mkono, vidole vya miguu, mikono au miguu hufa ganzi au kutikisita?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #2705321 (Pfirsichbaeumchen)'],
#  ['Any memory loss?',
#   'Je, wewe hupoteza fahamu?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #1313714 (Pfirsichbaeumchen)'],
#  ['Any trouble with balance or coordination?',
#   'Je, una matatizo kusimama wima au kujisawazisha?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #6626001 (Felixjp)'],
#  ['Have you had any falls?',
#   'Umewahi kuanguka?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #976 (MUIRIEL)'],
#  ['Any mood changes? Any insomnia?',
#   'Hisia zako zabadilika ghafla bila kukusudia? Je, unakosa usingizi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #444494 (Espi)'],
#  ['Do you feel down or depressed?',
#   'Je, unajihisi kusongwa na kusononeka?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #722128 (Pfirsichbaeumchen)'],
#  ['Have you lost pleasure in doing things?',
#   'Umekosa hamu au ari ya kufanya mambo?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1670006 (Pfirsichbaeumchen)'],
#  ['Do you see or hear people or things that are not there?',
#   'Je, wewe huona au husikia watu au vitu ambavyo havipo?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #2344583 (Vortarulo)'],
#  ['Any problem with sex or loss of sex drive?',
#   'Je, una matatizo na mambo ya ngono au kupoteza hamu ya ngono?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #373376 (lilygilder)'],
#  ['Any pain with sex?',
#   'Je, una uchungu wowote wakati wa ngono?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #808911 (Manfredo)'],
#  ['Any itching, rash or discharge?',
#   'Je, una mwasho, vipele au kutoa usaha kwenye ume au uke?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #937379 (Sudajaengi)'],
#  ['Any lesions or sores?',
#   'Je, una kuchibuka ngozi au vidonda kwenye ume au uke?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #397489 (MUIRIEL)'],
#  ['Any hernias?',
#   'Je, una vimbe zozote kwenye ume au uke?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4756673 (raggione)'],
#  ['Females: Any problems with your menses?  ',
#   'Wanawake : Je una matatizo yoyote unapokuwa katika hedhi? ',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #247763 (CK) & #1300435 (cumori) 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #2494159 (Pfirsichbaeumchen)'],
#  ['Date of your last menstrual period?',
#   'Ni lini ulipoenda hedhi mara ya mwisho?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4756673 (raggione)'],
#  ['Last Pap test?',
#   'Ni lini mara yako ya mwisho kufanyiwa uchunguzi wa kubaini kama una chembechembe zinazosababisha ugonjwa wa saratani ya sehemu ya uzazi?',
#   'CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4756673 (raggione)']]

# %%
#Have the text which was read be in array form. This will help us to utilize the data better in the next steps.
lang_eng = array(lang_eng)

# %%
lang_eng
# Out:
# array([['Any recent chills, night sweats or fever?',
#         'Kuumwa , kutokwa majasho usiku au joto lolote hivi majuzi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['Have you gained or lost weight without trying?',
#         'Je, umeongeza au kupunguza uzani bila kukusudia?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#        ['Have you been tired?', 'Je, umewahi kuchoka?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)'],
#        ['Any dry or itchy areas?',
#         'Maeneo yoyote yaliyokauka au yanayowasha?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)'],
#        ['Any rashes, bumps, or sores anywhere?',
#         'Vipele, majipu au vidonda popote?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)'],
#        ['Do you bruise easily?', 'Je, wewe huchibuka kwa urahisi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)'],
#        ['Have any of your moles changed in color, shape or size?Any changes in hair or nails?',
#         'Je, magamba yako yamegeuka rangi, umbo au ukubwa? Je pamekuwa na mabadiliko katika nyweleau kucha zako?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)'],
#        ['Have you had any dizziness (room spinning) or light-headedness?',
#         'Umewahi kuwa na kisuunzi (kizunguzungu) au kichwa kuwa kizito?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)'],
#        ['Have you fainted or passed out?', 'Umewahi kuzirai?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)'],
#        ['Do you have headaches? ', 'Waumwa na kichwa? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #2122375 (Pfirsichbaeumchen)'],
#        ['Have you ever had any head trauma?',
#         'Umewahi kupata mshtuko kichwani?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #626467 (jakov)'],
#        ['Any problems with your eyes, e.g., itching, burning, watering, discharge, redness, pain?',
#         'Matatizo yoyote kwenye macho yako kama vile kuwashwa, kuungua, kutoa machozi, kutoa matongo, kuwa mekundu au kuwa na maumivu?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #2122378 (Pfirsichbaeumchen)'],
#        ['Any problems with your vision, e.g., double vision, blurred vision?',
#         'Shida katika kuona mfano: kuona vitu viwili viwili, kutokuona vyema?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #8597806 (Roujin)'],
#        ['Do you wear glasses or contacts?',
#         ' Je, wewe huvaa miwani au lensi ziwekwazo machoni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #6102432 (mailohilohi) & #4942826 (Hans_Adler)'],
#        ['Any problems with your ears, e.g., ringing, pain, discharge, hearing problems?',
#         'Matatizo yoyote kwenye masikio yako kama vile kusikia sauti sikioni, maumivu masikioni, kutoa usaha, matatizo ya kusikia?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #6625701 (Felixjp)'],
#        ['Any history of frequent ear infections?',
#         'Matatizo ya awali ya maambukizo ya masikio? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #380701 (cburgmer)'],
#        ['Have you ever had tubes in your ears?',
#         'Umewahi kuwekewa mipira kwenye masikio yako?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['Do you wear a hearing aid?',
#         'Je wewe hutumia kifaa cha kukusaidia kusikia vizuri?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #131 (MUIRIEL)'],
#        ['Any problems with your nose, eg, bloody nose, runny nose, congestion, sneezing, change in mucus?',
#         'Matatizo yoyote kwenye pua yako? Kama vile mnoga - kutokwa damu puani, makamasi yanayotoka na kutiririka kila wakati, kuzibika kwa pua, kupiga chafya, mabadiliko kwenye makamasi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #1169837 (Haehnchenpaella)'],
#        ['Any recent sore throat or sores in your mouth?',
#         'Vidonda kooni au vidonda mdomoni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #5828607 (CK) & #6643977 (Felixjp)'],
#        ['Any problem with your teeth or gums, e.g., pain, bleeding or loose teeth?',
#         'Matatizo ya meno au ufizi kama vile kuuma, kutoka damu au meno kung’oka?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #547386 (Espi)'],
#        ['Any hoarseness?', 'Kuwasha kwa koo?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #5677459 (eric2)'],
#        ['Any lumps or bumps in your neck?', 'Vimbe au kufura shingoni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #4944510 (Hans_Adler)'],
#        ['Any soreness, pain or stiffness?',
#         'Vidonda, uchungu au kukwama shingoni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941621 (Hans_Adler)'],
#        ['Any pain with movement?',
#         'Je, una matatizo yoyote kugeuka kwa shingo?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941622 (Hans_Adler)'],
#        ['Relax.', 'Entspann dich.',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #3172031 (dinkel_girl)'],
#        ['Any trouble with breathing or shortness of breath?',
#         'Je, una shida yoyote ya kupumua?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #1958697 (Tamy)'],
#        ['Any shortness of breath with exercise or movement or How far can you walk without having to stop?',
#         'Je, una matatizo yoyote kupumua unapofanya mazoezi au unapotembea? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #8597807 (Roujin)'],
#        ['Any pain when you take a deep breath?',
#         'Unatembea umbali gani bila ya kupumzika?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['Any cough or phlegm production?',
#         'Kukohoa kwokote au kuwa na makamasi puani au kooni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #4659632 (AC)'],
#        ['Have you ever had tuberculosis?',
#         'Umewahi kuugua ugonjwa wa kifua kikuu?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5227364 (jaz1313)'],
#        ['Have you been exposed to anyone with tuberculosis?',
#         'Umewahi kutangamana na yeyote anayeugua ugonjwa wa kifua kikuu?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5946689 (list)'],
#        ['Do you have any chest pains?', 'Je,una maumivu yoyote kifuani?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #957535 (Sudajaengi)'],
#        ['Do you feel like your heart races or skips beats?',
#         'Je, wahisi kuwa moyo wako una mapigo ya kasi au hata kukosa mapigo?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4768107 (garborg) & #8597873 (Roujin)'],
#        ['Do you have shortness of breath at rest or with small amounts of exertion?',
#         'Je, una upungufu fulani unapopumua?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4769344 (garborg) & #8227448 (MisterTrouser)'],
#        ['Can you lie flat in bed without shortness of breath?',
#         'Je, waweza kujilaza twaa kitandani bila ya kuwa na matatizo ya kupumua?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155388 (Pfirsichbaeumchen)'],
#        ['Do you ever awake at night short of breath?',
#         'Je, wewe huzinduka usingizini usiku kwa sababu ya tatizo la kupumua?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155390 (Pfirsichbaeumchen)'],
#        ['Have you ever been told you have a heart murmur?',
#         'Je, umewahi kuambiwa una shida ya moyo? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5253180 (christian42)'],
#        ['Have you ever had rheumatic fever?',
#         'Je, umewahi kuwa na maumivu ya viungo na kufura / kuvimba viungoni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#        ['Any pains in your legs or buttocks when you walk? ',
#         'Maumivu yoyote miguuni au makalioni / matakoni unapotembea? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5622431 (list)'],
#        ['Does it get better when you stop?', 'Inakua bora unaposimama?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin) '],
#        ['Any loss of hair from your legs or sores that don’t heal?',
#         'Kutoweka kwa malaika miguuni au vidonda visivyopona?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #8597813 (Roujin)'],
#        ['Any problems with leg swelling or varicose veins?',
#         'Je, miguu yako inafura au mshipa mikubwa kujitokeza miguuni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #455377 (MUIRIEL)'],
#        ['Any breast lumps, pain or soreness?',
#         'Je, una vimbe matitini, uchungu wowote au vidonda vyovyote?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #455452 (Zaghawa)'],
#        ['Any nipple discharge?',
#         'Je, unatoa usaha wowote kwenye chuchu?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #1808892 (Tamy)'],
#        ['Any rashes, color changes or skin changes?',
#         'Je, una vipele, kubadilika kwa rangi matitini au ngozi kubadilika?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401396 (Esperantostern)'],
#        ['When was your last mammogram?',
#         'Ni lini mara ya mwisho kufanyiwa uchunguzi wa matiti yako kubaini iwapo una saratani ya matiti?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401397 (Esperantostern)'],
#        ['Any belly ache/abdominal pain?',
#         'Kuumwa kwa tumbo kwa aina yoyote?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #4659678 (AC)'],
#        ['Any nausea, vomiting, cramping, diarrhea?',
#         'Kichefuchefu chochote, kutapika, tumbo kusokota, kuhara / kuendesha?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846595 (Pfirsichbaeumchen)'],
#        ['Any heartburn?', 'Kiungulia chochote?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846597 (Pfirsichbaeumchen)'],
#        ['Any constipation?', 'Haja ngumu yoyote?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1854006 (Pfirsichbaeumchen)'],
#        ['Any blood in the stool or black tarry stool? Any food intolerance?',
#         'Damu yoyote kwenye haja kubwa / kinyesi? Kutokubalika kwa chakula tumboni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942958 (Hans_Adler)'],
#        ['Any problems with gallstones? ',
#         'Damu yoyote kwenye haja kubwa / kinyesi? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942959 (Hans_Adler)'],
#        ['Hepatitis?', 'Kutokubalika kwa chakula tumboni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#        ['Any increase in frequency of urination?',
#         'Kuongezeka kwa mara / idadi ya nyakati wa kukojoa?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942960 (Hans_Adler)'],
#        ['Do you have to get up at night to urinate? ',
#         'Je, wewe huamka na kukojoa usiku? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942961 (Hans_Adler)'],
#        ['How many times?', ' Mara ngapi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['Do you feel like you need to urinate, then cannot?',
#         'Je, wahisi kutaka kukojoa kisha unashindwa kukojoa?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942963 (Hans_Adler)'],
#        ['Any pain with urination?', 'Je, una uchungu wowote unapokojoa?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #358382 (MUIRIEL)'],
#        ['Any blood in your urine?', 'Je, una damu kwenye mkojo wako?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3935374 (gianich73) & #3235040 (Manfredo)'],
#        ['Any pain in your back or flanks?',
#         'Una maumivu mgongoni au kiunoni?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1755073 (Eldad) & #4659717 (AC)'],
#        ['Any weakness?', 'Una upungufu au udhaifu wowote misulini?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7141489 (Luiaard)'],
#        ['Any joint pain, redness, swelling, heat?',
#         'Je, kuvimba au joto misulini?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7141490 (Luiaard)'],
#        ['Any morning stiffness?',
#         'Je, misuli yako hukauka na kuwa migumu wakati wa asubuhi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #7290637 (shekitten) & #4781463 (Tamy)'],
#        ['Any limited movement?', 'Je, unapungukiwa ukitembea?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #5828611 (CK) & #7091837 (Luiaard)'],
#        ['Any muscle cramping or pain?',
#         'Je, misuli yako hujisokota na kuwa na uchungu mkali?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #341452 (MUIRIEL)'],
#        ['Any numbness or tingling in fingers, toes, arms or legs?',
#         'Je, vidole vya mkono, vidole vya miguu, mikono au miguu hufa ganzi au kutikisita?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #2705321 (Pfirsichbaeumchen)'],
#        ['Any memory loss?', 'Je, wewe hupoteza fahamu?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #1313714 (Pfirsichbaeumchen)'],
#        ['Any trouble with balance or coordination?',
#         'Je, una matatizo kusimama wima au kujisawazisha?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #6626001 (Felixjp)'],
#        ['Have you had any falls?', 'Umewahi kuanguka?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #976 (MUIRIEL)'],
#        ['Any mood changes? Any insomnia?',
#         'Hisia zako zabadilika ghafla bila kukusudia? Je, unakosa usingizi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #444494 (Espi)'],
#        ['Do you feel down or depressed?',
#         'Je, unajihisi kusongwa na kusononeka?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #722128 (Pfirsichbaeumchen)'],
#        ['Have you lost pleasure in doing things?',
#         'Umekosa hamu au ari ya kufanya mambo?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1670006 (Pfirsichbaeumchen)'],
#        ['Do you see or hear people or things that are not there?',
#         'Je, wewe huona au husikia watu au vitu ambavyo havipo?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #2344583 (Vortarulo)'],
#        ['Any problem with sex or loss of sex drive?',
#         'Je, una matatizo na mambo ya ngono au kupoteza hamu ya ngono?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #373376 (lilygilder)'],
#        ['Any pain with sex?', 'Je, una uchungu wowote wakati wa ngono?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #808911 (Manfredo)'],
#        ['Any itching, rash or discharge?',
#         'Je, una mwasho, vipele au kutoa usaha kwenye ume au uke?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #937379 (Sudajaengi)'],
#        ['Any lesions or sores?',
#         'Je, una kuchibuka ngozi au vidonda kwenye ume au uke?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #397489 (MUIRIEL)'],
#        ['Any hernias?', 'Je, una vimbe zozote kwenye ume au uke?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4756673 (raggione)'],
#        ['Females: Any problems with your menses?  ',
#         'Wanawake : Je una matatizo yoyote unapokuwa katika hedhi? ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #247763 (CK) & #1300435 (cumori) 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #2494159 (Pfirsichbaeumchen)'],
#        ['Date of your last menstrual period?',
#         'Ni lini ulipoenda hedhi mara ya mwisho?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4756673 (raggione)'],
#        ['Last Pap test?',
#         'Ni lini mara yako ya mwisho kufanyiwa uchunguzi wa kubaini kama una chembechembe zinazosababisha ugonjwa wa saratani ya sehemu ya uzazi?',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4756673 (raggione)']],
#       dtype='<U178')

# %%
#Will use 50 lines from the dataset for the training part. 
lang_eng = lang_eng[:50,:]

# %%
#this gets rid of punctuations and has the text be lowercase. All of this is done to clean data.
lang_eng[:,0] = [s.translate(str.maketrans('', '', string.punctuation)) for s in lang_eng[:,0]]
lang_eng[:,1] = [s.translate(str.maketrans('', '', string.punctuation)) for s in lang_eng[:,1]]
for i in range(len(lang_eng)):
    lang_eng[i,0] = lang_eng[i,0].lower()
    lang_eng[i,1] = lang_eng[i,1].lower()

# %%
lang_eng
# Out:
# array([['any recent chills night sweats or fever',
#         'kuumwa  kutokwa majasho usiku au joto lolote hivi majuzi',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['have you gained or lost weight without trying',
#         'je umeongeza au kupunguza uzani bila kukusudia',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#        ['have you been tired', 'je umewahi kuchoka',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)'],
#        ['any dry or itchy areas',
#         'maeneo yoyote yaliyokauka au yanayowasha',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)'],
#        ['any rashes bumps or sores anywhere',
#         'vipele majipu au vidonda popote',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)'],
#        ['do you bruise easily', 'je wewe huchibuka kwa urahisi',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)'],
#        ['have any of your moles changed in color shape or sizeany changes in hair or nails',
#         'je magamba yako yamegeuka rangi umbo au ukubwa je pamekuwa na mabadiliko katika nyweleau kucha zako',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)'],
#        ['have you had any dizziness room spinning or lightheadedness',
#         'umewahi kuwa na kisuunzi kizunguzungu au kichwa kuwa kizito',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)'],
#        ['have you fainted or passed out', 'umewahi kuzirai',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)'],
#        ['do you have headaches ', 'waumwa na kichwa ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #2122375 (Pfirsichbaeumchen)'],
#        ['have you ever had any head trauma',
#         'umewahi kupata mshtuko kichwani',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #626467 (jakov)'],
#        ['any problems with your eyes eg itching burning watering discharge redness pain',
#         'matatizo yoyote kwenye macho yako kama vile kuwashwa kuungua kutoa machozi kutoa matongo kuwa mekundu au kuwa na maumivu',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #2122378 (Pfirsichbaeumchen)'],
#        ['any problems with your vision eg double vision blurred vision',
#         'shida katika kuona mfano kuona vitu viwili viwili kutokuona vyema',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #8597806 (Roujin)'],
#        ['do you wear glasses or contacts',
#         ' je wewe huvaa miwani au lensi ziwekwazo machoni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #6102432 (mailohilohi) & #4942826 (Hans_Adler)'],
#        ['any problems with your ears eg ringing pain discharge hearing problems',
#         'matatizo yoyote kwenye masikio yako kama vile kusikia sauti sikioni maumivu masikioni kutoa usaha matatizo ya kusikia',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #6625701 (Felixjp)'],
#        ['any history of frequent ear infections',
#         'matatizo ya awali ya maambukizo ya masikio ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #380701 (cburgmer)'],
#        ['have you ever had tubes in your ears',
#         'umewahi kuwekewa mipira kwenye masikio yako',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['do you wear a hearing aid',
#         'je wewe hutumia kifaa cha kukusaidia kusikia vizuri',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #131 (MUIRIEL)'],
#        ['any problems with your nose eg bloody nose runny nose congestion sneezing change in mucus',
#         'matatizo yoyote kwenye pua yako kama vile mnoga  kutokwa damu puani makamasi yanayotoka na kutiririka kila wakati kuzibika kwa pua kupiga chafya mabadiliko kwenye makamasi',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #1169837 (Haehnchenpaella)'],
#        ['any recent sore throat or sores in your mouth',
#         'vidonda kooni au vidonda mdomoni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #5828607 (CK) & #6643977 (Felixjp)'],
#        ['any problem with your teeth or gums eg pain bleeding or loose teeth',
#         'matatizo ya meno au ufizi kama vile kuuma kutoka damu au meno kung’oka',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #547386 (Espi)'],
#        ['any hoarseness', 'kuwasha kwa koo',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #5677459 (eric2)'],
#        ['any lumps or bumps in your neck', 'vimbe au kufura shingoni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #4944510 (Hans_Adler)'],
#        ['any soreness pain or stiffness',
#         'vidonda uchungu au kukwama shingoni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941621 (Hans_Adler)'],
#        ['any pain with movement',
#         'je una matatizo yoyote kugeuka kwa shingo',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941622 (Hans_Adler)'],
#        ['relax', 'entspann dich',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #3172031 (dinkel_girl)'],
#        ['any trouble with breathing or shortness of breath',
#         'je una shida yoyote ya kupumua',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #1958697 (Tamy)'],
#        ['any shortness of breath with exercise or movement or how far can you walk without having to stop',
#         'je una matatizo yoyote kupumua unapofanya mazoezi au unapotembea ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #8597807 (Roujin)'],
#        ['any pain when you take a deep breath',
#         'unatembea umbali gani bila ya kupumzika',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'],
#        ['any cough or phlegm production',
#         'kukohoa kwokote au kuwa na makamasi puani au kooni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #4659632 (AC)'],
#        ['have you ever had tuberculosis',
#         'umewahi kuugua ugonjwa wa kifua kikuu',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5227364 (jaz1313)'],
#        ['have you been exposed to anyone with tuberculosis',
#         'umewahi kutangamana na yeyote anayeugua ugonjwa wa kifua kikuu',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5946689 (list)'],
#        ['do you have any chest pains', 'jeuna maumivu yoyote kifuani',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #957535 (Sudajaengi)'],
#        ['do you feel like your heart races or skips beats',
#         'je wahisi kuwa moyo wako una mapigo ya kasi au hata kukosa mapigo',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4768107 (garborg) & #8597873 (Roujin)'],
#        ['do you have shortness of breath at rest or with small amounts of exertion',
#         'je una upungufu fulani unapopumua',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #4769344 (garborg) & #8227448 (MisterTrouser)'],
#        ['can you lie flat in bed without shortness of breath',
#         'je waweza kujilaza twaa kitandani bila ya kuwa na matatizo ya kupumua',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155388 (Pfirsichbaeumchen)'],
#        ['do you ever awake at night short of breath',
#         'je wewe huzinduka usingizini usiku kwa sababu ya tatizo la kupumua',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155390 (Pfirsichbaeumchen)'],
#        ['have you ever been told you have a heart murmur',
#         'je umewahi kuambiwa una shida ya moyo ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5253180 (christian42)'],
#        ['have you ever had rheumatic fever',
#         'je umewahi kuwa na maumivu ya viungo na kufura  kuvimba viungoni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'],
#        ['any pains in your legs or buttocks when you walk ',
#         'maumivu yoyote miguuni au makalioni  matakoni unapotembea ',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5622431 (list)'],
#        ['does it get better when you stop', 'inakua bora unaposimama',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin) '],
#        ['any loss of hair from your legs or sores that don’t heal',
#         'kutoweka kwa malaika miguuni au vidonda visivyopona',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #8597813 (Roujin)'],
#        ['any problems with leg swelling or varicose veins',
#         'je miguu yako inafura au mshipa mikubwa kujitokeza miguuni',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #455377 (MUIRIEL)'],
#        ['any breast lumps pain or soreness',
#         'je una vimbe matitini uchungu wowote au vidonda vyovyote',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #455452 (Zaghawa)'],
#        ['any nipple discharge', 'je unatoa usaha wowote kwenye chuchu',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #1808892 (Tamy)'],
#        ['any rashes color changes or skin changes',
#         'je una vipele kubadilika kwa rangi matitini au ngozi kubadilika',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401396 (Esperantostern)'],
#        ['when was your last mammogram',
#         'ni lini mara ya mwisho kufanyiwa uchunguzi wa matiti yako kubaini iwapo una saratani ya matiti',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401397 (Esperantostern)'],
#        ['any belly acheabdominal pain',
#         'kuumwa kwa tumbo kwa aina yoyote',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #4659678 (AC)'],
#        ['any nausea vomiting cramping diarrhea',
#         'kichefuchefu chochote kutapika tumbo kusokota kuhara  kuendesha',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846595 (Pfirsichbaeumchen)'],
#        ['any heartburn', 'kiungulia chochote',
#         'CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846597 (Pfirsichbaeumchen)']],
#       dtype='<U178')

# %%
#In the encoder-decoder algorithm, the input and output sentences have to be "tokenized" into integer sequences of fixed length.
#The Tokenizer() class provided by Keras will turn sequences for both the input and output (both the language and english part) into integer sequences. 
def tokenization(lines):
      tokenizer = Tokenizer()
      tokenizer.fit_on_texts(lines)
      return tokenizer

# %%
#This is to tokenize the english pairs.
eng_tokenizer = tokenization(lang_eng[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1

eng_length = 10
print('English Vocabulary Size: %d' % eng_vocab_size)
# Out:
# English Vocabulary Size: 168

# %%
#This is to tokenize the language part
lang_tokenizer = tokenization(lang_eng[:, 1])
lang_vocab_size = len(lang_tokenizer.word_index) + 1

lang_length = 10
print('Language Vocabulary Size: %d' % lang_vocab_size)
# Out:
# Language Vocabulary Size: 207

# %%
#This is the function for the encoder sequence. What is happening here is that the input sentence has been read and now will be encoded to a fixed length integer sequence (tokenized)
#padding is done with 0 values to have the sentences be the same maximum length.
def encode_sequences(tokenizer, length, lines):
         seq = tokenizer.texts_to_sequences(lines)
         seq = pad_sequences(seq, maxlen=length, padding='post')
         return seq

# %%
# Now it is time for the model building part. We first split data for training and testing. We have to train the model and use those observations to make predictions on the unseen data which is the testing data.
train, test = train_test_split(lang_eng, test_size=0.4, random_state = 12)

# %%
#Now we will use the function encode_sequences which was mentioned above. Input sequence would be the sentences for language and the target sequence would be english sentences.
#This has to be done for testing and training shown below.

trainX = encode_sequences(lang_tokenizer, lang_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
testX = encode_sequences(lang_tokenizer, lang_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])

# %%
#Now, to build the model:
#The encoder part has the first/embedding layer and LSTM model.
#The decoder part has a LSTM model and dense layer which helps to return the output.
def define_model(in_vocab,out_vocab, in_timesteps,out_timesteps,units):
      model = Sequential()
      model.add(Embedding(in_vocab, units, input_length=in_timesteps, mask_zero=True))
      model.add(LSTM(units))
      model.add(RepeatVector(out_timesteps))
      model.add(LSTM(units, return_sequences=True))
      model.add(Dense(out_vocab, activation='softmax'))
      return model

# %%
# Use the function from above to build the model
model = define_model(lang_vocab_size, eng_vocab_size, lang_length, eng_length, 80)

# %%
#RMSprop optimizer is used in the model with sparse categorical crossentropy as loss function.
#What will happen is that the target sequence will be as it is and we can use it like that. Otherwise, that target sequence could be changed by having a binary number for each integer value.
rms = optimizers.RMSprop(lr=0.001)
model.compile(optimizer=rms, loss='sparse_categorical_crossentropy')

# %%
#Training the model now: As seen below, 80% of data is used to train the model. 20% is used to test the model and see if the predictions are good.

#What the ModelCheckpoint() function does is it saves the best model with the lowest validation loss.
filename = 'model.h1.24_jan_19'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# trained model with 13 epochs, batch size of 80 with 20% of validation split, and lowest validation loss
history = model.fit(trainX, trainY.reshape(trainY.shape[0], trainY.shape[1], 1),
                    epochs=13, batch_size=80, validation_split = 0.2,callbacks=[checkpoint], 
                    verbose=1)
# Out:
# /Users/saumyapandey/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 24 samples, validate on 6 samples
# Epoch 1/13
# 24/24 [==============================] - 3s 113ms/step - loss: 5.1231 - val_loss: 5.1138
#
# Epoch 00001: val_loss improved from inf to 5.11382, saving model to model.h1.24_jan_19
# Epoch 2/13
# 24/24 [==============================] - 0s 2ms/step - loss: 5.1034 - val_loss: 5.0980
#
# Epoch 00002: val_loss improved from 5.11382 to 5.09796, saving model to model.h1.24_jan_19
# Epoch 3/13
# 24/24 [==============================] - 0s 3ms/step - loss: 5.0724 - val_loss: 5.0650
#
# Epoch 00003: val_loss improved from 5.09796 to 5.06503, saving model to model.h1.24_jan_19
# Epoch 4/13
# 24/24 [==============================] - 0s 2ms/step - loss: 5.0070 - val_loss: 4.9854
#
# Epoch 00004: val_loss improved from 5.06503 to 4.98539, saving model to model.h1.24_jan_19
# Epoch 5/13
# 24/24 [==============================] - 0s 3ms/step - loss: 4.8482 - val_loss: 4.7924
#
# Epoch 00005: val_loss improved from 4.98539 to 4.79237, saving model to model.h1.24_jan_19
# Epoch 6/13
# 24/24 [==============================] - 0s 3ms/step - loss: 4.4612 - val_loss: 4.6263
#
# Epoch 00006: val_loss improved from 4.79237 to 4.62631, saving model to model.h1.24_jan_19
# Epoch 7/13
# 24/24 [==============================] - 0s 2ms/step - loss: 3.9785 - val_loss: 4.6466
#
# Epoch 00007: val_loss did not improve from 4.62631
# Epoch 8/13
# 24/24 [==============================] - 0s 5ms/step - loss: 3.7901 - val_loss: 4.6208
#
# Epoch 00008: val_loss improved from 4.62631 to 4.62076, saving model to model.h1.24_jan_19
# Epoch 9/13
# 24/24 [==============================] - 0s 3ms/step - loss: 3.7047 - val_loss: 4.6105
#
# Epoch 00009: val_loss improved from 4.62076 to 4.61048, saving model to model.h1.24_jan_19
# Epoch 10/13
# 24/24 [==============================] - 0s 3ms/step - loss: 3.6442 - val_loss: 4.5972
#
# Epoch 00010: val_loss improved from 4.61048 to 4.59715, saving model to model.h1.24_jan_19
# Epoch 11/13
# 24/24 [==============================] - 0s 2ms/step - loss: 3.5967 - val_loss: 4.5848
#
# Epoch 00011: val_loss improved from 4.59715 to 4.58475, saving model to model.h1.24_jan_19
# Epoch 12/13
# 24/24 [==============================] - 0s 2ms/step - loss: 3.5571 - val_loss: 4.5786
#
# Epoch 00012: val_loss improved from 4.58475 to 4.57863, saving model to model.h1.24_jan_19
# Epoch 13/13
# 24/24 [==============================] - 0s 2ms/step - loss: 3.5227 - val_loss: 4.5689
#
# Epoch 00013: val_loss improved from 4.57863 to 4.56892, saving model to model.h1.24_jan_19

# %%
#Here the plot will be comparing training and validation loss. 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.show()

# %%
#We use the model which has the lowest validation loss and make predicitions on the testing data. 
model = load_model('model.h1.24_jan_19')
preds = model.predict_classes(testX.reshape((testX.shape[0],testX.shape[1])))
# Out:
# /Users/saumyapandey/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
#The predictions outputted are in the form of integer sequences since that's how it was encoded. We need the integer sequences to be returned as words it corresponds to.
#This is the function for it.
def get_word(n, tokenizer):
      for word, index in tokenizer.word_index.items():
          if index == n:
              return word
      return None

# %%
#We use the function from above to have the integer sequences be returned as words.
preds_text = []
for i in preds:
       temp = []
       for j in range(len(i)):
            t = get_word(i[j], eng_tokenizer)
            if j > 0:
                if (t == get_word(i[j-1], eng_tokenizer)) or (t == None):
                     temp.append('')
                else:
                     temp.append(t)
            else:
                   if(t == None):
                          temp.append('')
                   else:
                          temp.append(t) 

       preds_text.append(' '.join(temp))

# %%
#A format where we have the actual translation and predicted translations
pred_df = pd.DataFrame({'actual' : test[:,0], 'predicted' : preds_text})

# %%
# print 15 rows randomly to see some actual and predicted translations and how the model performs
pred_df.sample(15)
# Out:
#                                                                     actual  \
# 8                            any recent sore throat or sores in your mouth
# 16                       any trouble with breathing or shortness of breath
# 18                        do you feel like your heart races or skips beats
# 9                                           have you fainted or passed out
# 17                                                  do you have headaches
# 15  any problems with your ears eg ringing pain discharge hearing problems
# 5                                           any cough or phlegm production
# 19                                            any belly acheabdominal pain
# 13                                  any history of frequent ear infections
# 1                                             when was your last mammogram
# 7                                    any nausea vomiting cramping diarrhea
# 0                                     any pain when you take a deep breath
# 4                               do you ever awake at night short of breath
# 2              have you had any dizziness room spinning or lightheadedness
# 12                         have you ever been told you have a heart murmur
#
#     predicted
# 8
# 16
# 18
# 9
# 17
# 15
# 5
# 19
# 13
# 1
# 7
# 0
# 4
# 2
# 12
